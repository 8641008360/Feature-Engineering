# %% [markdown]
# # Assignment Questions

# %% [markdown]
# 1.
#
#    - A parameter is a value that describes a characteristic of a population in statistics or a component used to define a function, method, or model in mathematics and programming.
#
# 2.
#
#    - Correlation is a statistical measure that describes the strength and direction of a relationship between two variables.
#
#
# 3.
#
#    - achine Learning (ML) is a field of artificial intelligence (AI) that focuses on developing algorithms that allow computers to learn from data and make decisions or predictions without being explicitly programmed.
#
#       Main Components of Machine Learning
#
#        * Data
#        * Model
#        * Features
#
#
# 4.
#
#    - The loss value is a key indicator in machine learning that tells us how well (or poorly) a model is performing during training or testing.
#
# 5.
#
#   - n data science and statistics, variables are the features or characteristics you measure. They are mainly divided into two types:
#
#      Continuous Variables
#
#        - Variables that can take any numerical value within a range, including fractions or decimals.
#
#      Categorical Variables
#
#
#        - Variables that represent groups or categories; the values are labels or names, not numbers.
#
#
# 6.
#
#    - We encode them into a format that models can understand. Here are the most common techniques:
#
#       * Label Encoding
#       * One-Hot Encoding
#       * Ordinal Encoding
#       * Frequency / Count Encoding
#       * Target / Mean Encoding
#
#
# 7.
#
#    - In machine learning, we split the dataset into two main parts: training and testing. This helps us build a model and then evaluate how well it performs on new, unseen data.
#
#
# 8.
#
#    - sklearn.preprocessing is a module in Scikit-learn (sklearn), a popular Python machine learning library. This module contains tools to prepare (or "preprocess") data before using it in machine learning models.
#
#
# 9.
#
#    - A test set is a portion of your dataset that is used to evaluate the performance of your trained machine learning model. It is not used during training — it only checks how well the model generalizes to unseen data.
#
#
# 10.
#
#    - To split your dataset into training and testing sets, the most commonly used tool in Python is:
#
#        * Step 1: Import Required Libraries
#        * Step 2: Prepare Your Data
#        * Step 3: Split the Data
#        * Step 4: Check the Results
#
# 11.
#
#
#    - EDA is a crucial first step in any data science or machine learning project. It involves analyzing and visualizing the data to understand its structure, patterns, and issues before feeding it into a model.
#
#
#      * Understand the Data
#      * Detect and Handle Missing Values
#      * Identify and Treat Outliers
#      * Examine Class Imbalance
#
#
# 12.
#
#
#     - Correlation is a statistical measure that describes the strength and direction of a relationship between two variables.
#
#
# 13.
#
#    - Negative correlation means that as one variable increases, the other decreases, and vice versa.
#
#
# 14.
#
#    - You can easily find the correlation between variables in Python using libraries like Pandas, NumPy, or Seaborn (for visualization).
#
#
#       * Step 1: Import Libraries
#       * Step 2: Create or Load Your Dataset
#       * Step 3: Compute Correlation Matrix
#
#
# 15.
#
#    - Causation means that one variable directly affects or causes a change in another variable.
#
#          Correlation
#
#           * Variables move together
#           * No clear direction
#           * Just statistical association
#
#          Causation
#
#           * One variable directly affects another
#           * Clear direction: A → B
#           * Requires controlled testing or strong evidence
#
# 16.
#
#
#    - An optimizer is an algorithm used to adjust the model's parameters (like weights and biases) to minimize the loss function during training.
#    Most Common Types of Optimizers
#       * Gradient Descent (GD)
#       * Momentum
#       * Adagrad (Adaptive Gradient)
#       * RMSProp (Root Mean Square Propagation)
#       * Adam (Adaptive Moment Estimation)
#
#
# 17.
#
#    - sklearn.linear_model is a module in Scikit-learn that contains linear models for regression and classification tasks.
#
#
# 18.
#
#    - model.fit() is a core function in Scikit-learn and other ML frameworks used to train a machine learning model on your dataset.
#
#
# 19.
#
#
#    - model.predict() is used after training your model (with model.fit()) to make predictions on new or unseen data.
#
#
# 20.
#
#
#     -Continuous Variables
#        * Variables that can take any numeric value within a range, including fractions and decimals.
#
#      - Categorical Variables
#        * Variables that represent categories or labels. They take on a limited, fixed number of possible values, often as names or codes.
#
# 21.
#
#    - eature scaling is the process of normalizing or standardizing the range of independent variables (features) in your dataset.
#
#
# 22.
#
#    - In Python, the most common way to scale features is using Scikit-learn’s preprocessing module. Here's a complete guide with code examples for different scaling methods.
#
#      * Step 1: Import Required Libraries
#      * Step 2: Prepare Sample Data
#
# 23.
#
#    - sklearn.preprocessing is a module in Scikit-learn that provides a collection of data transformation tools to prepare (or preprocess) your data before feeding it into a machine learning model.
#
#
# 24.
#
#    - In machine learning, we split the dataset into two parts:
#
# Training set → used to train the model
#
# Testing set → used to evaluate the model's performance on unseen data
#
# This helps ensure that your model can generalize well to new data.
#
#
# 25.
#
#    - Data encoding is the process of converting categorical (non-numeric) data into a numerical format so that it can be used in machine learning models.
